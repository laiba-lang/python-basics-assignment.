# %% [markdown]
# <a href="https://colab.research.google.com/github/laiba-lang/python-basics-assignment./blob/master/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
unit=[1,12,30,78,0,23,60]
newunit=[x for x in unit if x ==0 else 100]
# Out:
#   File "/tmp/ipython-input-3929682270.py", line 2
#     newunit=[x for x in unit if x ==0, else 100]
#                                      ^
# SyntaxError: invalid syntax
